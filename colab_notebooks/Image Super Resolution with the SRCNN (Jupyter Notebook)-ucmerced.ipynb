# %% [markdown]
# ## Using The Super Resolution Convolutional Neural Network for Image Restoration
#
#
# Welcome to this tutorial on single-image super-resolution.  The goal of super-resolution (SR) is to recover a high resolution image from a low resolution input, or as they might say on any modern crime show, **enhance!**
#
# To accomplish this goal, we will be deploying the super-resolution convolution neural network (SRCNN) using Keras.  This network was published in the paper, "Image Super-Resolution Using Deep Convolutional Networks" by Chao Dong, et al. in 2014.  You can read the full paper at https://arxiv.org/abs/1501.00092.
#
# As the title suggests, the SRCNN is a deep convolutional neural network that learns end-to-end mapping of low resolution to high resolution images.  As a result, we can use it to improve the image quality of low resolution images.  To evaluate the performance of this network, we will be using three image quality metrics: peak signal to noise ratio (PSNR), mean squared error (MSE), and the structural similarity (SSIM) index.
#
# Furthermore, we will be using OpenCV, the Open Source Computer Vision Library.  OpenCV was originally developed by Intel and is used for many real-time computer vision applications.  In this particular project, we will be using it to pre and post process our images.  As you will see later, we will frequently be converting our images back and forth between the RGB, BGR, and YCrCb color spaces.  This is necessary because the SRCNN network was trained on the luminance (Y) channel in the YCrCb color space.
#
# During this project, you will learn how to:
#
# * use the PSNR, MSE, and SSIM image quality metrics,
# * process images using OpenCV,
# * convert between the RGB, BGR, and YCrCb color spaces,
# * build deep neural networks in Keras,
# * deploy and evaluate the SRCNN network
#
# ### 1. Importing Packages
# Let's dive right in! In this first cell, we will import the libraries and packages we will be using in this project and print their version numbers.  This is an important step to make sure we are all on the same page; furthermore, it will help others reproduce the results we obtain.

# %%
# check package versions
import sys
import matplotlib
from multiprocessing import Pool

print('Python: {}'.format(sys.version))
print('Matplotlib: {}'.format(matplotlib.__version__))
# Out:
# Python: 3.7.10 (default, May  3 2021, 02:48:31)
# [GCC 7.5.0]
# Matplotlib: 3.2.2

# %%
# import the necessary packages
from tensorflow.keras.layers import Dense, Conv2D, MaxPool2D, UpSampling2D, Add, Dropout
from keras.optimizers import Adam
from keras.preprocessing import image
from tensorflow.keras import Model, Input
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.backend import clear_session

from skimage.measure import compare_ssim as ssim
from sklearn.model_selection import train_test_split 
from matplotlib import pyplot as plt
import numpy as np
import math
import os
import glob
import cv2
import pandas as pd


# python magic function, displays pyplot figures in the notebook
# %matplotlib inline

# %%
# !git clone https://github.com/0xtaha/image-super-resloution-for-remote-sensing
# Out:
# Cloning into 'image-super-resloution-for-remote-sensing'...
# remote: Enumerating objects: 344, done.
# remote: Counting objects: 100% (344/344), done.
# remote: Compressing objects: 100% (232/232), done.
# remote: Total 344 (delta 191), reused 219 (delta 94), pack-reused 0
# Receiving objects: 100% (344/344), 6.04 MiB | 13.43 MiB/s, done.
# Resolving deltas: 100% (191/191), done.

# %%
# !cp -a /content/image-super-resloution-for-remote-sensing/. /content/
# !rm -rf /content/image-super-resloution-for-remote-sensing/

# %% [markdown]
# ## Downloading the Dataset

# %%
# !wget http://weegee.vision.ucmerced.edu/datasets/UCMerced_LandUse.zip
# !unzip /content/UCMerced_LandUse.zip -d /content/
# Out:
# --2021-07-08 16:59:43--  http://weegee.vision.ucmerced.edu/datasets/UCMerced_LandUse.zip
# Resolving weegee.vision.ucmerced.edu (weegee.vision.ucmerced.edu)... 169.236.184.65
# Connecting to weegee.vision.ucmerced.edu (weegee.vision.ucmerced.edu)|169.236.184.65|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 332468434 (317M) [application/zip]
# Saving to: ‘UCMerced_LandUse.zip.1’
#
# UCMerced_LandUse.zi 100%[===================>] 317.07M  33.1MB/s    in 11s
#
# 2021-07-08 16:59:54 (29.2 MB/s) - ‘UCMerced_LandUse.zip.1’ saved [332468434/332468434]
#
# Archive:  /content/UCMerced_LandUse.zip
# replace /content/UCMerced_LandUse/Images/agricultural/agricultural00.tif? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural00.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural01.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural02.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural03.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural04.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural05.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural06.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural07.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural08.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural09.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural10.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural11.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural12.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural13.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural14.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural15.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural16.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural17.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural18.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural19.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural20.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural21.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural22.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural23.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural24.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural25.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural26.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural27.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural28.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural29.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural30.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural31.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural32.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural33.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural34.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural35.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural36.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural37.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural38.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural39.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural40.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural41.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural42.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural43.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural44.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural45.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural46.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural47.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural48.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural49.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural50.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural51.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural52.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural53.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural54.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural55.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural56.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural57.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural58.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural59.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural60.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural61.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural62.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural63.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural64.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural65.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural66.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural67.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural68.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural69.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural70.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural71.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural72.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural73.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural74.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural75.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural76.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural77.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural78.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural79.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural80.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural81.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural82.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural83.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural84.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural85.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural86.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural87.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural88.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural89.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural90.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural91.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural92.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural93.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural94.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural95.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural96.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural97.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural98.tif
#   inflating: /content/UCMerced_LandUse/Images/agricultural/agricultural99.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane00.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane01.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane02.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane03.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane04.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane05.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane06.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane07.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane08.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane09.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane10.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane11.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane12.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane13.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane14.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane15.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane16.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane17.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane18.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane19.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane20.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane21.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane22.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane23.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane24.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane25.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane26.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane27.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane28.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane29.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane30.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane31.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane32.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane33.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane34.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane35.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane36.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane37.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane38.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane39.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane40.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane41.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane42.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane43.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane44.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane45.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane46.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane47.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane48.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane49.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane50.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane51.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane52.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane53.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane54.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane55.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane56.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane57.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane58.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane59.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane60.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane61.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane62.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane63.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane64.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane65.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane66.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane67.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane68.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane69.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane70.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane71.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane72.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane73.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane74.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane75.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane76.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane77.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane78.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane79.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane80.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane81.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane82.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane83.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane84.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane85.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane86.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane87.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane88.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane89.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane90.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane91.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane92.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane93.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane94.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane95.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane96.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane97.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane98.tif
#   inflating: /content/UCMerced_LandUse/Images/airplane/airplane99.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond00.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond01.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond02.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond03.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond04.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond05.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond06.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond07.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond08.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond09.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond10.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond11.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond12.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond13.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond14.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond15.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond16.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond17.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond18.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond19.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond20.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond21.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond22.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond23.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond24.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond25.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond26.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond27.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond28.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond29.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond30.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond31.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond32.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond33.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond34.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond35.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond36.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond37.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond38.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond39.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond40.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond41.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond42.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond43.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond44.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond45.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond46.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond47.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond48.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond49.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond50.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond51.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond52.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond53.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond54.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond55.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond56.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond57.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond58.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond59.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond60.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond61.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond62.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond63.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond64.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond65.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond66.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond67.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond68.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond69.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond70.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond71.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond72.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond73.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond74.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond75.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond76.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond77.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond78.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond79.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond80.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond81.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond82.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond83.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond84.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond85.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond86.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond87.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond88.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond89.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond90.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond91.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond92.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond93.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond94.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond95.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond96.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond97.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond98.tif
#   inflating: /content/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond99.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach00.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach01.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach02.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach03.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach04.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach05.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach06.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach07.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach08.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach09.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach10.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach11.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach12.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach13.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach14.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach15.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach16.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach17.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach18.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach19.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach20.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach21.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach22.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach23.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach24.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach25.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach26.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach27.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach28.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach29.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach30.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach31.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach32.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach33.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach34.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach35.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach36.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach37.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach38.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach39.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach40.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach41.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach42.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach43.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach44.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach45.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach46.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach47.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach48.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach49.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach50.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach51.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach52.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach53.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach54.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach55.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach56.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach57.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach58.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach59.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach60.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach61.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach62.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach63.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach64.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach65.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach66.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach67.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach68.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach69.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach70.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach71.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach72.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach73.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach74.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach75.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach76.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach77.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach78.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach79.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach80.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach81.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach82.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach83.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach84.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach85.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach86.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach87.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach88.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach89.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach90.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach91.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach92.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach93.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach94.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach95.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach96.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach97.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach98.tif
#   inflating: /content/UCMerced_LandUse/Images/beach/beach99.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings00.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings01.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings02.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings03.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings04.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings05.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings06.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings07.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings08.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings09.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings10.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings11.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings12.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings13.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings14.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings15.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings16.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings17.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings18.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings19.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings20.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings21.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings22.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings23.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings24.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings25.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings26.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings27.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings28.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings29.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings30.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings31.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings32.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings33.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings34.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings35.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings36.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings37.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings38.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings39.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings40.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings41.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings42.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings43.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings44.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings45.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings46.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings47.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings48.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings49.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings50.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings51.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings52.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings53.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings54.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings55.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings56.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings57.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings58.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings59.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings60.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings61.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings62.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings63.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings64.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings65.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings66.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings67.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings68.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings69.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings70.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings71.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings72.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings73.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings74.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings75.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings76.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings77.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings78.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings79.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings80.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings81.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings82.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings83.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings84.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings85.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings86.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings87.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings88.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings89.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings90.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings91.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings92.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings93.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings94.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings95.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings96.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings97.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings98.tif
#   inflating: /content/UCMerced_LandUse/Images/buildings/buildings99.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral00.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral01.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral02.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral03.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral04.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral05.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral06.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral07.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral08.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral09.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral10.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral11.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral12.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral13.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral14.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral15.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral16.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral17.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral18.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral19.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral20.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral21.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral22.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral23.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral24.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral25.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral26.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral27.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral28.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral29.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral30.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral31.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral32.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral33.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral34.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral35.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral36.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral37.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral38.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral39.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral40.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral41.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral42.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral43.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral44.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral45.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral46.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral47.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral48.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral49.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral50.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral51.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral52.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral53.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral54.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral55.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral56.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral57.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral58.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral59.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral60.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral61.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral62.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral63.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral64.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral65.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral66.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral67.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral68.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral69.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral70.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral71.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral72.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral73.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral74.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral75.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral76.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral77.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral78.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral79.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral80.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral81.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral82.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral83.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral84.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral85.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral86.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral87.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral88.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral89.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral90.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral91.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral92.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral93.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral94.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral95.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral96.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral97.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral98.tif
#   inflating: /content/UCMerced_LandUse/Images/chaparral/chaparral99.tif
#   inflating: /content/UCMerced_LandUse/Images/denseresidential/denseresidential00.tif
#   inflating: /content/UCMerced_LandUse/Images/denseresidential/denseresidential01.tif
#   inflating: /content/UCMerced_LandUse/Images/denseresidential/denseresidential02.tif
#   inflating: /content/UCMerced_LandUse/Images/denseresidential/denseresidential03.tif
#   inflating: /content/UCMerced_LandUse/Images/denseresidential/denseresidential04.tif
#   inflating: /content/UCMerced_LandUse/Images/denseresidential/denseresidential05.tif
#   inflating: /content/UCMerced_LandUse/Images/denseresidential/denseresidential06.tif
#   inflating: /content/UCMerced_LandUse/Images/denseresidential/denseresidential07.tif
#   inflating: /content/UCMerced_LandUse/Images/denseresidential/denseresidential08.tif
#   inflating: /content/UCMerced_LandUse/Images/denseresidential/denseresidential09.tif
#   inflating: /content/UCMerced_LandUse/Images/denseresidential/denseresidential10.tif
#   inflating: /content/UCMerced_LandUse/Images/denseresidential/denseresidential11.tif
#   inflating: /content/UCMerced_LandUse/Images/denseresidential/denseresidential12.tif
#   inflating: /content/UCMerced_LandUse/Images/denseresidential/denseresidential13.tif
#   inflating: /content/UCMerced_LandUse/Images/denseresidential/denseresidential14.tif
#   inflating: /content/UCMerced_LandUse/Images/denseresidential/denseresidential15.tif
#   inflating: /content/UCMerced_LandUse/Images/denseresidential/denseresidential16.tif
#   inflating: /content/UCMerced_LandUse/Images/denseresidential/denseresidential17.tif
#   inflating: /content/UCMerced_LandUse/Images/denseresidential/denseresidential18.tif
#   inflating: /content/UCMerced_LandUse/Images/denseresidential/denseresidential19.tif
#   inflating: /content/UCMerced_LandUse/Images/denseresidential/denseresidential20.tif
#   inflating: /content/UCMerced_LandUse/Images/denseresidential/denseresidential21.tif
#   inflating: /content/UCMerced_LandUse/Images/denseresidential/denseresidential22.tif
# ...
#   inflating: /content/UCMerced_LandUse/Images/sparseresidential/sparseresidential99.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks00.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks01.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks02.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks03.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks04.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks05.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks06.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks07.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks08.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks09.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks10.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks11.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks12.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks13.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks14.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks15.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks16.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks17.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks18.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks19.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks20.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks21.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks22.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks23.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks24.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks25.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks26.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks27.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks28.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks29.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks30.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks31.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks32.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks33.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks34.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks35.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks36.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks37.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks38.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks39.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks40.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks41.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks42.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks43.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks44.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks45.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks46.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks47.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks48.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks49.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks50.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks51.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks52.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks53.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks54.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks55.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks56.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks57.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks58.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks59.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks60.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks61.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks62.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks63.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks64.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks65.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks66.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks67.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks68.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks69.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks70.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks71.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks72.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks73.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks74.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks75.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks76.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks77.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks78.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks79.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks80.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks81.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks82.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks83.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks84.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks85.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks86.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks87.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks88.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks89.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks90.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks91.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks92.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks93.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks94.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks95.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks96.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks97.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks98.tif
#   inflating: /content/UCMerced_LandUse/Images/storagetanks/storagetanks99.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt00.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt01.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt02.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt03.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt04.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt05.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt06.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt07.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt08.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt09.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt10.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt11.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt12.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt13.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt14.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt15.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt16.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt17.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt18.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt19.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt20.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt21.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt22.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt23.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt24.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt25.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt26.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt27.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt28.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt29.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt30.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt31.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt32.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt33.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt34.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt35.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt36.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt37.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt38.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt39.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt40.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt41.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt42.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt43.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt44.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt45.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt46.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt47.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt48.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt49.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt50.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt51.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt52.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt53.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt54.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt55.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt56.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt57.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt58.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt59.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt60.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt61.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt62.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt63.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt64.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt65.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt66.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt67.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt68.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt69.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt70.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt71.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt72.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt73.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt74.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt75.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt76.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt77.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt78.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt79.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt80.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt81.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt82.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt83.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt84.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt85.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt86.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt87.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt88.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt89.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt90.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt91.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt92.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt93.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt94.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt95.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt96.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt97.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt98.tif
#   inflating: /content/UCMerced_LandUse/Images/tenniscourt/tenniscourt99.tif
#   inflating: /content/UCMerced_LandUse/readme.txt
#   inflating: /content/UCMerced_LandUse/readme.txt.bak

# %%
Land_images = glob.glob('/content/UCMerced_LandUse/Images/**/*.tif') #returns path of images
print(len(Land_images)) #contains 13243 images
# Out:
# 2100

# %% [markdown]
# ### 2. Image Quality Metrics
# To start, lets define a couple of functions that we can use to calculate the PSNR, MSE, and SSIM.  The structural similiarity (SSIM) index was imported directly from the scikit-image library; however, we will have to define our own functions for the PSNR and MSE.  Furthermore, we will wrap all three of these metrics into a single function that we can call later.

# %%
# define a function for peak signal-to-noise ratio (PSNR)
def psnr(target, ref):
         
    # assume RGB image
    target_data = target.astype(float)
    ref_data = ref.astype(float)

    diff = ref_data - target_data
    diff = diff.flatten('C')

    rmse = math.sqrt(np.mean(diff ** 2.))

    return 20 * math.log10(255. / rmse)

# define function for mean squared error (MSE)
def mse(target, ref):
    # the MSE between the two images is the sum of the squared difference between the two images
    err = np.sum((target.astype('float') - ref.astype('float')) ** 2)
    err /= float(target.shape[0] * target.shape[1])
    
    return err

# define function that combines all three image quality metrics
def compare_images(target, ref):
    scores = []
    scores.append(psnr(target, ref))
    scores.append(mse(target, ref))
    scores.append(ssim(target, ref, multichannel =True))
    
    return scores

# %% [markdown]
# ### 3. Preparing Images
#
# For this project, we will be using the same images that were used in the original SRCNN paper.  We can download these images from http://mmlab.ie.cuhk.edu.hk/projects/SRCNN.html.  The .zip file identified as the MATLAB code contains the images we want.  Copy both the Set5 and Set14 datasets into a new folder called 'source'.
#
# Now that we have some images, we want to produce low resolution versions of these same images.  We can accomplish this by resizing the images, both downwards and upwards, using OpeCV. There are several interpolation methods that can be used to resize images; however, we will be using bilinear interpolation.
#
# Once we produce these low resolution images, we can save them in a new folder.

# %%
# prepare degraded images by introducing quality distortions via resizing

from tqdm import tqdm
progress = tqdm(total= len(Land_images), position=0)
def read(path):
  img = image.load_img(path, target_size=(256,256,3))
  img = image.img_to_array(img)
  img = img/255.
  progress.update(1)
  return img

p = Pool(10)
img_array = p.map(read, Land_images)
# Out:
#   9%|▊         | 180/2100 [00:06<02:15, 14.13it/s]

# %%
def get_low_res(img , factor):
  # find old and new image dimensions
  h, w, _ = img.shape
  new_height = int(h / factor)
  new_width = int(w / factor)
          
  # resize the image - down
  img = cv2.resize(img, (new_width, new_height), interpolation = cv2.INTER_LINEAR)
          
  # resize the image - up
  low_img_resloution = cv2.resize(img, (w, h), interpolation = cv2.INTER_LINEAR)
  return low_img_resloution

# %%
all_images = np.array(img_array)
#Split test and train data. all_images will be our output images
train_x, val_x = train_test_split(all_images, random_state = 32, test_size=0.2 , train_size = 0.8)

# %%
all_images.shape
# Out:
# (2100, 256, 256, 3)

# %%
# get low resloution images for training
train_x_low = []

for i in range(train_x.shape[0]):
  temp = get_low_res(train_x[i,:,:,:] , 2)
  train_x_low.append(temp)
train_x_low = np.array(train_x_low)

val_x_low = []

for i in range(val_x.shape[0]):
  temp = get_low_res(val_x[i,:,:,:] , 2)
  val_x_low.append(temp)
val_x_low = np.array(val_x_low)

# %%
del all_images
del img_array

# %%
import gc
gc.collect()
# Out:
# 104

# %%
n = 2
plt.figure(figsize= (20,10))
for i in range(n):
  ax = plt.subplot(2, n, i+1)
  plt.imshow(train_x[i+20])
  ax.get_xaxis().set_visible(False)
  ax.get_yaxis().set_visible(False)
  ax = plt.subplot(2, n, i+1+n)
  plt.imshow(train_x_low[i+20])
  ax.get_xaxis().set_visible(False)
  ax.get_yaxis().set_visible(False)
plt.show()

# %% [markdown]
# ### 3. Testing Low Resolution Images
#
# To ensure that our image quality metrics are being calculated correctly and that the images were effectively degraded, lets calculate the PSNR, MSE, and SSIM between our reference images and the degraded images that we just prepared.

# %%
# test the generated images using the image quality metrics

for i in range(val_x.shape[0]):
    
    # open target and reference images
    target = val_x_low[i,:,:,:]
    ref = val_x[i,:,:,:]
    
    # calculate score
    scores = compare_images(target, ref)

    # print all three scores with new line characters (\n) 
    print('{}\nPSNR: {}\nMSE: {}\nSSIM: {}\n'.format(i, scores[0], scores[1], scores[2]))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: UserWarning: DEPRECATED: skimage.measure.compare_ssim has been moved to skimage.metrics.structural_similarity. It will be removed from skimage.measure in version 0.18.
# 0
# PSNR: 79.53821856555626
# MSE: 0.00216960043385051
# SSIM: 0.9675191291354254
#
# 1
# PSNR: 75.5955031230692
# MSE: 0.005378377770785346
# SSIM: 0.9045525065701701
#
# 2
# PSNR: 75.80162180773496
# MSE: 0.005129079549528043
# SSIM: 0.8743914512624814
#
# 3
# PSNR: 73.3753659525047
# MSE: 0.008967368573469463
# SSIM: 0.8943770742203522
#
# 4
# PSNR: 75.14212200061274
# MSE: 0.005970207360252928
# SSIM: 0.8884114820101553
#
# 5
# PSNR: 73.7362219355718
# MSE: 0.008252383879617691
# SSIM: 0.8875925297425358
#
# 6
# PSNR: 75.34034278628104
# MSE: 0.005703840032307619
# SSIM: 0.8969216157871815
#
# 7
# PSNR: 74.38296130806869
# MSE: 0.0071105874957051425
# SSIM: 0.9101927855821343
#
# 8
# PSNR: 72.94921492179245
# MSE: 0.009891909249765223
# SSIM: 0.8002029816334266
#
# 9
# PSNR: 71.62309277181615
# MSE: 0.013424321309847984
# SSIM: 0.8127891714156871
#
# 10
# PSNR: 71.20364518172165
# MSE: 0.01478553682996748
# SSIM: 0.8163234484499525
#
# 11
# PSNR: 71.7181371214833
# MSE: 0.013133724541868633
# SSIM: 0.8943170388708629
#
# 12
# PSNR: 77.92584202782191
# MSE: 0.003144976559105143
# SSIM: 0.9040547418686895
#
# 13
# PSNR: 72.09986115204943
# MSE: 0.012028611558468794
# SSIM: 0.9098139237087204
#
# 14
# PSNR: 72.20108769150671
# MSE: 0.011751487594045899
# SSIM: 0.890863171119119
#
# 15
# PSNR: 78.08006577703816
# MSE: 0.003035253984390131
# SSIM: 0.913593581622448
#
# 16
# PSNR: 80.32568342670828
# MSE: 0.0018098112058502099
# SSIM: 0.9310459677219983
#
# 17
# PSNR: 75.91247512111197
# MSE: 0.004999816937939364
# SSIM: 0.9341950633645988
#
# 18
# PSNR: 77.31850860769377
# MSE: 0.003617018706218893
# SSIM: 0.9665200954823715
#
# 19
# PSNR: 87.48989213109915
# MSE: 0.00034770617418556146
# SSIM: 0.9832585756272886
#
# 20
# PSNR: 79.17726815216145
# MSE: 0.002357625392454973
# SSIM: 0.9011722557844233
#
# 21
# PSNR: 80.12237907282042
# MSE: 0.0018965474301442242
# SSIM: 0.9296602290385617
#
# 22
# PSNR: 75.49095919215615
# MSE: 0.005509417654820376
# SSIM: 0.9564365040810682
#
# 23
# PSNR: 75.00487523414905
# MSE: 0.0061618921424644955
# SSIM: 0.8690998479090362
#
# 24
# PSNR: 76.79071182744434
# MSE: 0.004084420364217144
# SSIM: 0.9161467573378504
#
# 25
# PSNR: 75.41658733104532
# MSE: 0.005604577545481425
# SSIM: 0.9167339105773197
#
# 26
# PSNR: 74.97431216657691
# MSE: 0.006205408824222964
# SSIM: 0.9157994727707758
#
# 27
# PSNR: 88.36933712216842
# MSE: 0.0002839670196492422
# SSIM: 0.9879550158129135
#
# 28
# PSNR: 81.84424295503288
# MSE: 0.0012757844960332163
# SSIM: 0.9739772348291709
#
# 29
# PSNR: 72.92818849318118
# MSE: 0.009939917189735054
# SSIM: 0.8760359119145269
#
# 30
# PSNR: 87.25792680687475
# MSE: 0.00036678277747884683
# SSIM: 0.9794861846058778
#
# 31
# PSNR: 72.37386619112611
# MSE: 0.011293147395191048
# SSIM: 0.9134614984669737
#
# 32
# PSNR: 83.06467147392881
# MSE: 0.0009632399094420797
# SSIM: 0.9600456257211203
#
# 33
# PSNR: 83.50519558659695
# MSE: 0.0008703261987121118
# SSIM: 0.9689309960792557
#
# 34
# PSNR: 77.97989734901546
# MSE: 0.00310607458942234
# SSIM: 0.9299761781961089
#
# 35
# PSNR: 85.49069264362197
# MSE: 0.000550975580608125
# SSIM: 0.9748993484609428
#
# 36
# PSNR: 86.94827687880564
# MSE: 0.00039388906812946796
# SSIM: 0.9762853737224378
#
# 37
# PSNR: 76.98874261200045
# MSE: 0.0039023602066996055
# SSIM: 0.9351591537043672
#
# 38
# PSNR: 78.78772112123936
# MSE: 0.002578870317198802
# SSIM: 0.9282669140343066
#
# 39
# PSNR: 76.27935804761822
# MSE: 0.004594791519467601
# SSIM: 0.8686189024305749
#
# 40
# PSNR: 83.08195188803055
# MSE: 0.0009594148290408965
# SSIM: 0.9487342824591138
#
# 41
# PSNR: 78.10976349166202
# MSE: 0.003014569261045186
# SSIM: 0.9060270638609732
#
# 42
# PSNR: 70.37218080854201
# MSE: 0.01790537968659906
# SSIM: 0.8508697649997755
#
# 43
# PSNR: 80.08175337980269
# MSE: 0.0019143717533113413
# SSIM: 0.9670718364987523
#
# 44
# PSNR: 73.36360804535364
# MSE: 0.008991679346203114
# SSIM: 0.9028137669209285
#
# 45
# PSNR: 73.89620160154959
# MSE: 0.00795392433809808
# SSIM: 0.8097357384015219
#
# 46
# PSNR: 68.90661835797903
# MSE: 0.025092260048847695
# SSIM: 0.8326859733735267
#
# 47
# PSNR: 70.21655137921113
# MSE: 0.018558654112620965
# SSIM: 0.886423082569228
#
# 48
# PSNR: 77.75874190052191
# MSE: 0.00326834147795032
# SSIM: 0.9213275817491078
#
# 49
# PSNR: 76.95532005953892
# MSE: 0.003932507953287964
# SSIM: 0.8894191901617431
#
# 50
# PSNR: 73.93533670073816
# MSE: 0.007882571985435113
# SSIM: 0.8692460232546595
#
# 51
# PSNR: 77.78678534938257
# MSE: 0.003247304995632729
# SSIM: 0.9490950685761289
#
# 52
# PSNR: 78.45862263484189
# MSE: 0.00278188614865319
# SSIM: 0.9471300208741384
#
# 53
# PSNR: 74.71082698827323
# MSE: 0.006593544122899935
# SSIM: 0.8867635744312584
#
# 54
# PSNR: 78.81054013662327
# MSE: 0.0025653557655578607
# SSIM: 0.9175500879532889
#
# 55
# PSNR: 74.44241384602284
# MSE: 0.007013910680186301
# SSIM: 0.7983503701919231
#
# 56
# PSNR: 74.86999418253633
# MSE: 0.006356267959142286
# SSIM: 0.902383933131717
#
# 57
# PSNR: 85.3213842185205
# MSE: 0.0005728793840009591
# SSIM: 0.9704567881857343
#
# 58
# PSNR: 77.79735132933733
# MSE: 0.0032394142079154083
# SSIM: 0.8923013560767906
#
# 59
# PSNR: 79.71477986584233
# MSE: 0.002083164802333377
# SSIM: 0.9538632062089644
#
# 60
# PSNR: 78.72213330179443
# MSE: 0.0026181123867098327
# SSIM: 0.9266399523625437
#
# 61
# PSNR: 77.94483309856136
# MSE: 0.0031312540557555404
# SSIM: 0.9493047115459806
#
# 62
# PSNR: 78.2498267771664
# MSE: 0.0029188981270668823
# SSIM: 0.8802870463310973
#
# 63
# PSNR: 73.28281197168684
# MSE: 0.009160526141802882
# SSIM: 0.6818398320460437
#
# 64
# PSNR: 75.06991651236174
# MSE: 0.006070297337300396
# SSIM: 0.9033266108309507
#
# 65
# PSNR: 72.80948629825
# MSE: 0.010215343758993026
# SSIM: 0.853424129525668
#
# 66
# PSNR: 67.35467825804258
# MSE: 0.035870199308083904
# SSIM: 0.751424345382997
#
# 67
# PSNR: 69.20617761170413
# MSE: 0.02341983626237563
# SSIM: 0.893025305492147
#
# 68
# PSNR: 72.05019932376251
# MSE: 0.01216694887616517
# SSIM: 0.882896978198786
#
# 69
# PSNR: 79.08913809535001
# MSE: 0.002405956694325532
# SSIM: 0.9041824016880747
#
# 70
# PSNR: 71.16246988453616
# MSE: 0.01492638458201398
# SSIM: 0.7841439219467863
#
# 71
# PSNR: 75.8467949745612
# MSE: 0.0050760058990003
# SSIM: 0.911753425162829
#
# 72
# PSNR: 77.42322690446828
# MSE: 0.0035308472128694687
# SSIM: 0.8987930493372248
#
# 73
# PSNR: 74.96090054663425
# MSE: 0.006224601612794607
# SSIM: 0.848349445830871
#
# 74
# PSNR: 75.74501354759678
# MSE: 0.0051963723214221965
# SSIM: 0.8609699501912611
#
# 75
# PSNR: 77.0235058755624
# MSE: 0.003871248303389805
# SSIM: 0.9231343022379258
#
# 76
# PSNR: 78.8840546339424
# MSE: 0.0025222965867821674
# SSIM: 0.8849054955540461
#
# 77
# PSNR: 68.98543597186831
# MSE: 0.024640982392972036
# SSIM: 0.7818787902180077
#
# 78
# PSNR: 77.00874747807066
# MSE: 0.0038844261378822766
# SSIM: 0.9087077243282472
#
# 79
# PSNR: 73.93022750541343
# MSE: 0.007891850781403476
# SSIM: 0.8288134479468452
#
# 80
# PSNR: 87.19241916763464
# MSE: 0.0003723571510668768
# SSIM: 0.979122262437826
#
# 81
# PSNR: 69.45754752797599
# MSE: 0.022102778057497822
# SSIM: 0.6774453672224698
#
# 82
# PSNR: 78.93103783826334
# MSE: 0.0024951567375051287
# SSIM: 0.9409026009494464
#
# 83
# PSNR: 69.73269422677237
# MSE: 0.020745895831891556
# SSIM: 0.8819541700146819
#
# 84
# PSNR: 74.54680963407935
# MSE: 0.00684732043654376
# SSIM: 0.8866153987832033
#
# 85
# PSNR: 75.54491296369062
# MSE: 0.005441395826964701
# SSIM: 0.9273430297060417
#
# 86
# PSNR: 76.44393137436373
# MSE: 0.004423932359769495
# SSIM: 0.9339204168775036
#
# 87
# PSNR: 78.69449943205797
# MSE: 0.0026348243743687513
# SSIM: 0.9076610011501192
#
# 88
# PSNR: 77.79707100623455
# MSE: 0.0032396233084191805
# SSIM: 0.9105449881442479
#
# 89
# PSNR: 79.04134976404882
# MSE: 0.0024325772409007646
# SSIM: 0.9579035508802223
#
# 90
# PSNR: 94.37346041253983
# MSE: 7.1261600856334e-05
# SSIM: 0.9942686090316163
#
# 91
# PSNR: 71.75854591435191
# MSE: 0.01301208897147346
# SSIM: 0.7652252933752517
#
# 92
# PSNR: 78.77242150025698
# MSE: 0.00258797135817995
# SSIM: 0.9420173990289196
#
# 93
# PSNR: 75.27677765073753
# MSE: 0.005787937735787759
# SSIM: 0.9111565650472869
#
# 94
# PSNR: 76.65782589277123
# MSE: 0.004211327597315514
# SSIM: 0.8971861292352964
#
# 95
# PSNR: 77.33385728016165
# MSE: 0.003604258136799256
# SSIM: 0.8282042924238282
#
# 96
# PSNR: 77.02920285866676
# MSE: 0.0038661734110880964
# SSIM: 0.8905031302550622
#
# 97
# PSNR: 74.56326040146371
# MSE: 0.006821432333797535
# SSIM: 0.8638774225128274
#
# 98
# PSNR: 79.70635615706061
# MSE: 0.0020872092937264486
# SSIM: 0.955312312735133
#
# 99
# PSNR: 73.04809526774216
# MSE: 0.009669234407968342
# SSIM: 0.8876755992850182
#
# 100
# PSNR: 78.13482256739391
# MSE: 0.0029972250858222188
# SSIM: 0.9201033680741609
#
# 101
# PSNR: 80.83617935252389
# MSE: 0.0016091023916275057
# SSIM: 0.9410258685556526
#
# 102
# PSNR: 71.57461970965109
# MSE: 0.013574993947330482
# SSIM: 0.7384928213067564
#
# 103
# PSNR: 92.51234943405329
# MSE: 0.00010938724191324836
# SSIM: 0.9917699319945387
#
# 104
# PSNR: 85.4547960745817
# MSE: 0.0005555485368506853
# SSIM: 0.9709398385108156
#
# 105
# PSNR: 76.97983934104563
# MSE: 0.00391036846132463
# SSIM: 0.9405345637220434
#
# 106
# PSNR: 84.75580569374138
# MSE: 0.0006525608969091208
# SSIM: 0.9735908576767157
#
# 107
# PSNR: 70.215885183844
# MSE: 0.018561501175669466
# SSIM: 0.8622353690825116
#
# 108
# PSNR: 84.6978645567155
# MSE: 0.0006613253339600755
# SSIM: 0.9645338670393081
#
# 109
# PSNR: 75.62985508352716
# MSE: 0.0053360035179769675
# SSIM: 0.880487523196008
#
# 110
# PSNR: 74.86256707296388
# MSE: 0.00636714746387804
# SSIM: 0.8978761362674222
#
# 111
# PSNR: 74.45636198000994
# MSE: 0.00699142040288545
# SSIM: 0.8539052282047684
#
# 112
# PSNR: 73.07111670640762
# MSE: 0.009618114545785596
# SSIM: 0.893426355712307
#
# 113
# PSNR: 73.57393681279102
# MSE: 0.008566589061003944
# SSIM: 0.8516342017800191
#
# 114
# PSNR: 69.87878759686937
# MSE: 0.020059627122738212
# SSIM: 0.8677370594687254
#
# 115
# PSNR: 79.25895724659874
# MSE: 0.0023136938432722354
# SSIM: 0.9054401461558098
#
# 116
# PSNR: 86.8913265408775
# MSE: 0.00039908826844606185
# SSIM: 0.9857677589610064
#
# 117
# PSNR: 74.40021988927995
# MSE: 0.007082386553360219
# SSIM: 0.8567669961672362
#
# 118
# PSNR: 78.52701102191166
# MSE: 0.0027384228714586803
# SSIM: 0.9498874184761602
#
# 119
# PSNR: 73.85304821423209
# MSE: 0.008033351947491702
# SSIM: 0.7823339179503837
#
# 120
# PSNR: 79.32053646613835
# MSE: 0.0022811191423481028
# SSIM: 0.957812849786917
#
# 121
# PSNR: 77.89568886547998
# MSE: 0.003166888179621923
# SSIM: 0.933431275561898
#
# 122
# PSNR: 80.08230660886062
# MSE: 0.0019141279052606746
# SSIM: 0.9271230763159717
#
# 123
# PSNR: 78.07029816062617
# MSE: 0.003042088186133101
# SSIM: 0.9564180542785358
#
# 124
# PSNR: 78.02366700726454
# MSE: 0.003074927743092932
# SSIM: 0.9184510733505954
#
# 125
# PSNR: 69.06920948238502
# MSE: 0.02417022355780975
# SSIM: 0.8757092301941495
#
# 126
# PSNR: 78.00524790955112
# MSE: 0.003087996679230916
# SSIM: 0.9584650123766248
#
# 127
# PSNR: 76.14107342936599
# MSE: 0.004743449405216487
# SSIM: 0.8910956563151302
#
# 128
# PSNR: 82.83574948576556
# MSE: 0.0010153754693945918
# SSIM: 0.976140623559783
#
# 129
# PSNR: 76.66048865670506
# MSE: 0.004208746322467972
# SSIM: 0.9615704460116228
#
# 130
# PSNR: 81.22485738391227
# MSE: 0.0014713496056700543
# SSIM: 0.9558959635145885
#
# 131
# PSNR: 70.64370908103803
# MSE: 0.016820182650072624
# SSIM: 0.8748019749823799
#
# 132
# PSNR: 77.12204610829505
# MSE: 0.0037843997468349384
# SSIM: 0.9226154673707462
#
# 133
# PSNR: 68.47311765012103
# MSE: 0.027726168010400967
# SSIM: 0.8873161647180909
#
# 134
# PSNR: 73.00264490446467
# MSE: 0.00977095751958607
# SSIM: 0.8825081749424316
#
# 135
# PSNR: 77.91819593329957
# MSE: 0.003150518413676057
# SSIM: 0.9239795029702336
#
# 136
# PSNR: 83.49202149451871
# MSE: 0.0008729702952730257
# SSIM: 0.9590939330027134
#
# 137
# PSNR: 80.90329557933103
# MSE: 0.0015844263546465054
# SSIM: 0.9707831489182474
#
# 138
# PSNR: 73.00759244022348
# MSE: 0.009759832663479873
# SSIM: 0.924510819802785
#
# 139
# PSNR: 71.59016598154557
# MSE: 0.013526486936740025
# SSIM: 0.7866454930748268
#
# 140
# PSNR: 78.63346837921716
# MSE: 0.0026721127400764822
# SSIM: 0.9492860704262215
#
# 141
# PSNR: 90.2976322231743
# MSE: 0.00018215386608746707
# SSIM: 0.9903506488243031
#
# 142
# PSNR: 74.72573512442099
# MSE: 0.006570949101231349
# SSIM: 0.8839036584862977
#
# 143
# PSNR: 76.04690919045174
# MSE: 0.004847420515281966
# SSIM: 0.8319539137280563
#
# 144
# PSNR: 74.8030755092268
# MSE: 0.0064549675695361845
# SSIM: 0.9276411739606769
#
# 145
# PSNR: 77.23136713293147
# MSE: 0.00369032743830381
# SSIM: 0.9176718493203143
#
# 146
# PSNR: 85.97181252752574
# MSE: 0.000493196928016255
# SSIM: 0.9720657050512601
#
# 147
# PSNR: 74.25921528926563
# MSE: 0.0073161076424798676
# SSIM: 0.8946103280234036
#
# 148
# PSNR: 64.6709456731544
# MSE: 0.06654371581003028
# SSIM: 0.714185042131299
#
# 149
# PSNR: 73.94750362622601
# MSE: 0.007860519564262959
# SSIM: 0.8746637924834011
#
# 150
# PSNR: 76.91360214881779
# MSE: 0.003970465262166889
# SSIM: 0.9236498483653649
#
# 151
# PSNR: 80.99708919018147
# MSE: 0.0015505747109161414
# SSIM: 0.9472016518271354
#
# 152
# PSNR: 76.56679027377146
# MSE: 0.004300536006856501
# SSIM: 0.9322575069561743
#
# 153
# PSNR: 75.08869538675789
# MSE: 0.006044106064455424
# SSIM: 0.8498402625297411
#
# 154
# PSNR: 79.11452222680413
# MSE: 0.002391935105920741
# SSIM: 0.9198573083469933
#
# 155
# PSNR: 75.56617832376857
# MSE: 0.005414816993584143
# SSIM: 0.906162279250792
#
# 156
# PSNR: 66.32868162584855
# MSE: 0.04542902886385949
# SSIM: 0.7688915089063869
#
# 157
# PSNR: 78.75966350840919
# MSE: 0.0025955850541453116
# SSIM: 0.9364166597488911
#
# 158
# PSNR: 74.07423849304946
# MSE: 0.007634450195948419
# SSIM: 0.7077971711966299
#
# 159
# PSNR: 75.98123712428792
# MSE: 0.004921278049867228
# SSIM: 0.9209494447544156
#
# 160
# PSNR: 75.36533139510611
# MSE: 0.005671115287171636
# SSIM: 0.8869437612285953
#
# 161
# PSNR: 80.66126436868353
# MSE: 0.0016752328427766072
# SSIM: 0.9529289720193227
#
# 162
# PSNR: 77.27512396614469
# MSE: 0.0036533326565321017
# SSIM: 0.9292391502987929
#
# 163
# PSNR: 83.26213655927786
# MSE: 0.000920424053647758
# SSIM: 0.9436422024176356
#
# 164
# PSNR: 83.8329433062011
# MSE: 0.000807062716676135
# SSIM: 0.9614554196233858
#
# 165
# PSNR: 79.80312907606279
# MSE: 0.0020412147972783245
# SSIM: 0.9164577555719015
#
# 166
# PSNR: 83.39354526820328
# MSE: 0.0008929910141646946
# SSIM: 0.9841638987144671
#
# 167
# PSNR: 81.40143222917123
# MSE: 0.0014127274788448938
# SSIM: 0.9652109959807581
#
# 168
# PSNR: 85.16922514545601
# MSE: 0.0005933064928179774
# SSIM: 0.9801324817682929
#
# 169
# PSNR: 79.12706456595095
# MSE: 0.0023850372097084242
# SSIM: 0.9491696443679908
#
# 170
# PSNR: 78.29648725177398
# MSE: 0.0028877054360289165
# SSIM: 0.956922737154441
#
# 171
# PSNR: 80.26235654002991
# MSE: 0.0018363944078208026
# SSIM: 0.9268706252007078
#
# 172
# PSNR: 70.31850062650895
# MSE: 0.018128069308049298
# SSIM: 0.826638977445613
#
# 173
# PSNR: 77.89648972104928
# MSE: 0.003166304247218519
# SSIM: 0.9494169124122317
#
# 174
# PSNR: 78.33781941821428
# MSE: 0.0028603532665116183
# SSIM: 0.952378312517364
#
# 175
# PSNR: 74.48861236823774
# MSE: 0.006939694922617702
# SSIM: 0.7589705958376983
#
# 176
# PSNR: 77.1110938072058
# MSE: 0.0037939555192549714
# SSIM: 0.9194200911267302
#
# 177
# PSNR: 76.47420690107093
# MSE: 0.004393199499791225
# SSIM: 0.9369719363919279
#
# 178
# PSNR: 80.36979296258767
# MSE: 0.001791522716251182
# SSIM: 0.9587982865774026
#
# 179
# PSNR: 71.99461730726078
# MSE: 0.012323665019521094
# SSIM: 0.8576739993177949
#
# 180
# PSNR: 74.94856731799945
# MSE: 0.006242303551782691
# SSIM: 0.9046471460854972
#
# 181
# PSNR: 68.57365596009194
# MSE: 0.027091685139511663
# SSIM: 0.8960067562563935
#
# 182
# PSNR: 79.01209775140212
# MSE: 0.002449017229119394
# SSIM: 0.9190660991212146
#
# 183
# PSNR: 80.96589026964983
# MSE: 0.001561753862191947
# SSIM: 0.9604787241340452
#
# 184
# PSNR: 84.92875171226484
# MSE: 0.0006270850460224145
# SSIM: 0.9800813609344926
#
# 185
# PSNR: 76.53461721329526
# MSE: 0.004332513196925824
# SSIM: 0.8985135003612138
#
# 186
# PSNR: 66.33104009104541
# MSE: 0.0454043650237855
# SSIM: 0.7527126011154205
#
# 187
# PSNR: 78.83427755093959
# MSE: 0.0025513724431667655
# SSIM: 0.9305629955649112
#
# 188
# PSNR: 79.31605233441599
# MSE: 0.00228347563584263
# SSIM: 0.9629538206567855
#
# 189
# PSNR: 80.18814692201131
# MSE: 0.001868043234270311
# SSIM: 0.9273871009230898
#
# 190
# PSNR: 73.50957346528655
# MSE: 0.008694493138087386
# SSIM: 0.8579905509296988
#
# 191
# PSNR: 82.36438331585379
# MSE: 0.0011317833067154839
# SSIM: 0.9534823500350406
#
# 192
# PSNR: 82.08920544868222
# MSE: 0.0012058160790978751
# SSIM: 0.9642452705799637
#
# 193
# PSNR: 74.32614692657819
# MSE: 0.007204219274157542
# SSIM: 0.8330258110092147
#
# 194
# PSNR: 78.1212755356469
# MSE: 0.003006588984888292
# SSIM: 0.9695839067295541
#
# 195
# PSNR: 77.43946220196219
# MSE: 0.0035176724334456803
# SSIM: 0.9281864073643508
#
# 196
# PSNR: 75.65099419077723
# MSE: 0.0053100938461955235
# SSIM: 0.9349542636510318
#
# 197
# PSNR: 68.26251556540389
# MSE: 0.029103824243629322
# SSIM: 0.68761012429921
#
# 198
# PSNR: 71.24470001599929
# MSE: 0.014646424391002048
# SSIM: 0.8487735483203606
#
# 199
# PSNR: 75.37059752590163
# MSE: 0.005664242822335902
# SSIM: 0.9452469829974696
#
# 200
# PSNR: 82.91659233781218
# MSE: 0.0009966493361210898
# SSIM: 0.9596316042972165
#
# 201
# PSNR: 74.53931151454861
# MSE: 0.0068591525863665155
# SSIM: 0.85802338653257
#
# 202
# PSNR: 76.50987682480316
# MSE: 0.004357264593270404
# SSIM: 0.9174293235062473
#
# 203
# PSNR: 72.78494160376982
# MSE: 0.010273240499957387
# SSIM: 0.8187916365384673
#
# 204
# PSNR: 74.04132358702356
# MSE: 0.0076925310319933965
# SSIM: 0.8153985033170342
#
# 205
# PSNR: 72.22845543107023
# MSE: 0.011677666615948512
# SSIM: 0.8778478427831332
#
# 206
# PSNR: 75.51952083029684
# MSE: 0.005473303521379902
# SSIM: 0.903170867017892
#
# 207
# PSNR: 72.90280698831522
# MSE: 0.009998179206798272
# SSIM: 0.8108908664683773
#
# 208
# PSNR: 83.82523744130432
# MSE: 0.000808495992298641
# SSIM: 0.9686536221082876
#
# 209
# PSNR: 75.05400615203668
# MSE: 0.006092576631542209
# SSIM: 0.8896183433333613
#
# 210
# PSNR: 84.44772878492063
# MSE: 0.000700533223706721
# SSIM: 0.9631630641242154
#
# 211
# PSNR: 76.63062376016569
# MSE: 0.004237788124035667
# SSIM: 0.8636349516259664
#
# 212
# PSNR: 72.38645092858052
# MSE: 0.011260470125692361
# SSIM: 0.924822545055093
#
# 213
# PSNR: 74.52056925004237
# MSE: 0.006888817676059893
# SSIM: 0.883620468783454
#
# 214
# PSNR: 75.93704519876712
# MSE: 0.004971610490128106
# SSIM: 0.9115515021922814
#
# 215
# PSNR: 74.31043279836544
# MSE: 0.007230333601712487
# SSIM: 0.7972343049345442
#
# 216
# PSNR: 72.34038822495654
# MSE: 0.011380537995960156
# SSIM: 0.8532976982926307
#
# 217
# PSNR: 76.89309935964154
# MSE: 0.003989253912245982
# SSIM: 0.9502933351230367
#
# 218
# PSNR: 75.0409661455499
# MSE: 0.006110897525456903
# SSIM: 0.8500818893328131
#
# 219
# PSNR: 76.23789613387143
# MSE: 0.0046388678659484645
# SSIM: 0.8777522682300024
#
# 220
# PSNR: 78.7926554124474
# MSE: 0.002575941965210921
# SSIM: 0.8813641140352244
#
# 221
# PSNR: 75.28408068873588
# MSE: 0.0057782129957895815
# SSIM: 0.8534974426132923
#
# 222
# PSNR: 67.13494525884626
# MSE: 0.03773176228841013
# SSIM: 0.7652886164436413
#
# 223
# PSNR: 77.62400551249553
# MSE: 0.0033713284409302153
# SSIM: 0.8864507004020038
#
# 224
# PSNR: 79.2010887324526
# MSE: 0.0023447294721219876
# SSIM: 0.908781418460502
#
# 225
# PSNR: 80.37617403220368
# MSE: 0.0017888923726964482
# SSIM: 0.9339657440407266
#
# 226
# PSNR: 83.69836610187488
# MSE: 0.00083246312579619
# SSIM: 0.9751205519228936
#
# 227
# PSNR: 81.62640610947469
# MSE: 0.001341408347622759
# SSIM: 0.9361050455608035
#
# 228
# PSNR: 76.92801889175045
# MSE: 0.003957306846354006
# SSIM: 0.9321621559899147
#
# 229
# PSNR: 76.46400250331703
# MSE: 0.004403534115033041
# SSIM: 0.924716421672405
#
# 230
# PSNR: 75.95024547763116
# MSE: 0.004956522338366804
# SSIM: 0.9041421910085868
#
# 231
# PSNR: 74.65093520713793
# MSE: 0.006685102874994268
# SSIM: 0.8782303812492017
#
# 232
# PSNR: 76.18211814139624
# MSE: 0.004698830741954829
# SSIM: 0.8800999504088521
#
# 233
# PSNR: 78.48446044031442
# MSE: 0.0027653848009604304
# SSIM: 0.8522703778669886
#
# 234
# PSNR: 83.570189123884
# MSE: 0.0008573984680423578
# SSIM: 0.9785098044171061
#
# 235
# PSNR: 81.55309849187131
# MSE: 0.0013642431015469221
# SSIM: 0.9530154127395268
#
# 236
# PSNR: 80.88721428857652
# MSE: 0.0015903041297254102
# SSIM: 0.9615575095682604
#
# 237
# PSNR: 65.8795183450304
# MSE: 0.050379027652871465
# SSIM: 0.75996296757918
#
# 238
# PSNR: 82.85023035183269
# MSE: 0.0010119954978006834
# SSIM: 0.9724206882226075
#
# 239
# PSNR: 81.94927243995525
# MSE: 0.0012453010996343302
# SSIM: 0.9448628483799038
#
# 240
# PSNR: 74.20270385508007
# MSE: 0.007411928651601763
# SSIM: 0.9034358390470606
#
# 241
# PSNR: 68.43656361653314
# MSE: 0.027960520639191647
# SSIM: 0.7898261074003742
#
# 242
# PSNR: 69.97804029941422
# MSE: 0.019606387675050765
# SSIM: 0.8388987318860002
#
# 243
# PSNR: 80.79764731550499
# MSE: 0.0016234423986559734
# SSIM: 0.9524335396373997
#
# 244
# PSNR: 78.04578240966038
# MSE: 0.0030593092133644182
# SSIM: 0.9529158546599205
#
# 245
# PSNR: 74.19906580505585
# MSE: 0.007418140166059634
# SSIM: 0.8586331899361334
#
# 246
# PSNR: 76.43696698780177
# MSE: 0.004431032309953827
# SSIM: 0.8958053724859262
#
# 247
# PSNR: 66.13499847937936
# MSE: 0.04750089227432609
# SSIM: 0.7609177017315295
#
# 248
# PSNR: 73.45400662095645
# MSE: 0.008806451618691355
# SSIM: 0.8659241105313198
#
# 249
# PSNR: 75.18407561082944
# MSE: 0.005912811779936846
# SSIM: 0.8921840625268818
#
# 250
# PSNR: 75.9915850496146
# MSE: 0.004909566089761152
# SSIM: 0.8808074343405649
#
# 251
# PSNR: 78.17192580361245
# MSE: 0.0029717278560429175
# SSIM: 0.9234939289714569
#
# 252
# PSNR: 78.52905229921403
# MSE: 0.002737136056357741
# SSIM: 0.9389066604920312
#
# 253
# PSNR: 78.74193589707873
# MSE: 0.0026062017128676775
# SSIM: 0.9044054753258061
#
# 254
# PSNR: 83.8252867287619
# MSE: 0.000808486816845706
# SSIM: 0.964606179234604
#
# 255
# PSNR: 79.61394274484124
# MSE: 0.00213209887547316
# SSIM: 0.9369733229386467
#
# 256
# PSNR: 77.93128760983586
# MSE: 0.0031410355707280012
# SSIM: 0.9237753085246694
#
# 257
# PSNR: 73.74915903315268
# MSE: 0.008227837622992621
# SSIM: 0.8998020469398739
#
# 258
# PSNR: 73.89322361087255
# MSE: 0.007959380275589602
# SSIM: 0.8941544157860863
#
# 259
# PSNR: 71.24485821657537
# MSE: 0.014645890874995874
# SSIM: 0.7095990379878896
#
# 260
# PSNR: 72.41016015925857
# MSE: 0.011199163875768744
# SSIM: 0.8856491646686643
#
# 261
# PSNR: 73.42845523180473
# MSE: 0.008858416429972456
# SSIM: 0.7104340017838252
#
# 262
# PSNR: 68.87432063994966
# MSE: 0.02527956238485314
# SSIM: 0.7746229626961024
#
# 263
# PSNR: 73.81088509606879
# MSE: 0.008111722889304647
# SSIM: 0.9214704787819885
#
# 264
# PSNR: 64.83633422631902
# MSE: 0.06405723563976826
# SSIM: 0.7449441008806764
#
# 265
# PSNR: 68.62187636798208
# MSE: 0.026792545615408524
# SSIM: 0.7537597115330316
#
# 266
# PSNR: 76.57971818630193
# MSE: 0.0042877533701327795
# SSIM: 0.9252940045727326
#
# 267
# PSNR: 80.73357762833308
# MSE: 0.001647569913911729
# SSIM: 0.9314798062104369
#
# 268
# PSNR: 79.00331461506687
# MSE: 0.002453975113378985
# SSIM: 0.9391290741063932
#
# 269
# PSNR: 76.53898046822617
# MSE: 0.00432816260823452
# SSIM: 0.9082697357738888
#
# 270
# PSNR: 82.08554548842356
# MSE: 0.0012068326932237901
# SSIM: 0.9502587293676076
#
# 271
# PSNR: 72.39736690082873
# MSE: 0.011232202524858351
# SSIM: 0.8760394105591239
#
# 272
# PSNR: 82.28018051058368
# MSE: 0.0011539408943587203
# SSIM: 0.9739639338615027
#
# 273
# PSNR: 76.2131847429252
# MSE: 0.00466533829848083
# SSIM: 0.8444023767188202
#
# 274
# PSNR: 71.36491489989805
# MSE: 0.014246563743630883
# SSIM: 0.890494179403083
#
# 275
# PSNR: 76.0658947865719
# MSE: 0.004826275807424434
# SSIM: 0.9039538570576103
#
# 276
# PSNR: 73.67286948887121
# MSE: 0.00837364734523435
# SSIM: 0.8752560916087786
#
# 277
# PSNR: 75.61781854726416
# MSE: 0.005350812843871828
# SSIM: 0.9455012250164518
#
# 278
# PSNR: 76.3069656569112
# MSE: 0.004565675590550721
# SSIM: 0.9110753003970821
#
# 279
# PSNR: 81.20816833814631
# MSE: 0.001477014577975065
# SSIM: 0.9623833907217335
#
# 280
# PSNR: 76.82470257158681
# MSE: 0.0040525777756604785
# SSIM: 0.8759794569618045
#
# 281
# PSNR: 69.23411466877386
# MSE: 0.023269665946584916
# SSIM: 0.8549761089890828
#
# 282
# PSNR: 77.92815039142546
# MSE: 0.003143305384196194
# SSIM: 0.9457619589515249
#
# 283
# PSNR: 70.0597612224089
# MSE: 0.01924090491283143
# SSIM: 0.7600450889222105
#
# 284
# PSNR: 76.41769985147646
# MSE: 0.004450733909561819
# SSIM: 0.924253922749729
#
# 285
# PSNR: 75.29888332688235
# MSE: 0.005758551867518479
# SSIM: 0.9228591987732591
#
# 286
# PSNR: 77.97171159778462
# MSE: 0.0031119345603756233
# SSIM: 0.9007937956987447
#
# 287
# PSNR: 75.93372129883655
# MSE: 0.004975416999736996
# SSIM: 0.9229127010312118
#
# 288
# PSNR: 74.45518202124111
# MSE: 0.006993320198748486
# SSIM: 0.7687780686548947
#
# 289
# PSNR: 74.24041575983375
# MSE: 0.00734784589926349
# SSIM: 0.8871684607788662
#
# 290
# PSNR: 66.92937566956776
# MSE: 0.039560707386520365
# SSIM: 0.7404238773102972
#
# 291
# PSNR: 74.62475289905127
# MSE: 0.006725527079800309
# SSIM: 0.8275448090695234
#
# 292
# PSNR: 76.70008386739113
# MSE: 0.004170549007094334
# SSIM: 0.9042243132516088
#
# 293
# PSNR: 77.25344307814267
# MSE: 0.0036716164568264607
# SSIM: 0.9364198674702392
#
# 294
# PSNR: 76.79059742201406
# MSE: 0.004084527960800455
# SSIM: 0.9300580453208717
#
# 295
# PSNR: 74.99173793447184
# MSE: 0.006180559932959179
# SSIM: 0.8754270659860858
#
# 296
# PSNR: 80.4403497649894
# MSE: 0.0017626522475423614
# SSIM: 0.9111112950352588
#
# 297
# PSNR: 70.14799508182806
# MSE: 0.01885393942425887
# SSIM: 0.8436193972739529
#
# 298
# PSNR: 71.72559643597819
# MSE: 0.013111185803732607
# SSIM: 0.5704409613692816
#
# 299
# PSNR: 75.91552377108309
# MSE: 0.00499630841005427
# SSIM: 0.8887519901875764
#
# 300
# PSNR: 80.91976154430675
# MSE: 0.0015784304889616154
# SSIM: 0.9616977494982635
#
# 301
# PSNR: 78.83459725524362
# MSE: 0.0025511846317247907
# SSIM: 0.9212577271268968
#
# 302
# PSNR: 76.3283948715475
# MSE: 0.004543202853344797
# SSIM: 0.8714560939333643
#
# 303
# PSNR: 77.63265548804083
# MSE: 0.003364620345910955
# SSIM: 0.9500763581374096
#
# 304
# PSNR: 74.4660915456665
# MSE: 0.006975774948817206
# SSIM: 0.8983191297605592
#
# 305
# PSNR: 87.76234234286191
# MSE: 0.0003265633039536505
# SSIM: 0.9816819030281194
#
# 306
# PSNR: 77.05286030638317
# MSE: 0.0038451703511403375
# SSIM: 0.7756668400259823
#
# 307
# PSNR: 76.30384267198284
# MSE: 0.004568959920537257
# SSIM: 0.8670335594013975
#
# 308
# PSNR: 82.99858504651209
# MSE: 0.000978009584588478
# SSIM: 0.9545588915521552
#
# 309
# PSNR: 78.06799590189559
# MSE: 0.003043701269209418
# SSIM: 0.9373142181012838
#
# 310
# PSNR: 78.53161641445176
# MSE: 0.002735520502597474
# SSIM: 0.957767896832103
#
# 311
# PSNR: 72.5071976487564
# MSE: 0.010951707869164051
# SSIM: 0.8480685637358004
#
# 312
# PSNR: 71.57885064356788
# MSE: 0.01356177551214403
# SSIM: 0.7619340436942608
#
# 313
# PSNR: 78.74615740878399
# MSE: 0.0026036696140299014
# SSIM: 0.9617369899460977
#
# 314
# PSNR: 79.94412362547506
# MSE: 0.001976010523003061
# SSIM: 0.909867982386039
#
# 315
# PSNR: 69.66674725880246
# MSE: 0.021063323102866627
# SSIM: 0.8487507206749298
#
# 316
# PSNR: 74.97060377138583
# MSE: 0.006210709820873445
# SSIM: 0.8032428639861839
#
# 317
# PSNR: 77.9962156920398
# MSE: 0.0030944256076471414
# SSIM: 0.9301428016083427
#
# 318
# PSNR: 77.39600739968354
# MSE: 0.003553046371754101
# SSIM: 0.8586903339889503
#
# 319
# PSNR: 75.64416769503555
# MSE: 0.0053184471269506015
# SSIM: 0.9518314848793291
#
# 320
# PSNR: 72.68113600984306
# MSE: 0.010521750871921759
# SSIM: 0.8741728407663841
#
# 321
# PSNR: 82.54164849329979
# MSE: 0.0010865176015187367
# SSIM: 0.9777415441753945
#
# 322
# PSNR: 79.05402223933837
# MSE: 0.002425489459556504
# SSIM: 0.913751176470098
#
# 323
# PSNR: 77.55727678003203
# MSE: 0.003423528420976342
# SSIM: 0.9550850366149021
#
# 324
# PSNR: 78.50357795799252
# MSE: 0.002753238410568818
# SSIM: 0.8873235794129367
#
# 325
# PSNR: 79.74904838804679
# MSE: 0.0020667920235283195
# SSIM: 0.9584182008667631
#
# 326
# PSNR: 79.42378540773346
# MSE: 0.0022275275024524134
# SSIM: 0.9630056630502799
#
# 327
# PSNR: 90.28282549474491
# MSE: 0.00018277595683175235
# SSIM: 0.9893859848972992
#
# 328
# PSNR: 75.80750387834667
# MSE: 0.005122137442789434
# SSIM: 0.8402087375175936
#
# 329
# PSNR: 76.19848422561337
# MSE: 0.004681156848825648
# SSIM: 0.8466899070545066
#
# 330
# PSNR: 76.61908885392423
# MSE: 0.00424905869375956
# SSIM: 0.9344885821123935
#
# 331
# PSNR: 86.3663768729113
# MSE: 0.00045036427018387443
# SSIM: 0.974909016533644
#
# 332
# PSNR: 82.57774888680055
# MSE: 0.0010775234412632505
# SSIM: 0.9718397096522305
#
# 333
# PSNR: 81.26790857316509
# MSE: 0.0014568363135213428
# SSIM: 0.9333844943903619
#
# 334
# PSNR: 75.76574363394238
# MSE: 0.005171627691180926
# SSIM: 0.9112506746363684
#
# 335
# PSNR: 80.31877077352058
# MSE: 0.0018126941711074395
# SSIM: 0.9636789125570583
#
# 336
# PSNR: 72.44026275192276
# MSE: 0.011121806642227491
# SSIM: 0.8569121729271755
#
# 337
# PSNR: 76.23721391014514
# MSE: 0.004639596632819237
# SSIM: 0.8331076390320996
#
# 338
# PSNR: 70.39468418217167
# MSE: 0.017812841247110373
# SSIM: 0.853605340565423
#
# 339
# PSNR: 73.1026149779886
# MSE: 0.009548609170093036
# SSIM: 0.8753154525275142
#
# 340
# PSNR: 79.56772111547738
# MSE: 0.0021549118235373033
# SSIM: 0.8799051125255201
#
# 341
# PSNR: 76.85675207688149
# MSE: 0.004022781163533573
# SSIM: 0.9508017346286644
#
# 342
# PSNR: 87.36394609663641
# MSE: 0.0003579373396691366
# SSIM: 0.979622049203911
#
# 343
# PSNR: 70.44917704744162
# MSE: 0.01759073195102803
# SSIM: 0.7351204985155756
#
# 344
# PSNR: 83.93600953605704
# MSE: 0.0007881350864228399
# SSIM: 0.9817278624157907
#
# 345
# PSNR: 74.66758287522083
# MSE: 0.006659526141719128
# SSIM: 0.8542631731889717
#
# 346
# PSNR: 79.34209973501915
# MSE: 0.0022698211691886882
# SSIM: 0.9585851536172711
#
# 347
# PSNR: 72.83711385346987
# MSE: 0.010150565319062024
# SSIM: 0.8970402155584143
#
# 348
# PSNR: 78.48284537523284
# MSE: 0.0027664133903584675
# SSIM: 0.9234201575321328
#
# 349
# PSNR: 79.93932057296765
# MSE: 0.0019781970882989442
# SSIM: 0.9197978312995211
#
# 350
# PSNR: 75.44740446619204
# MSE: 0.005564948748505782
# SSIM: 0.8832425206808905
#
# 351
# PSNR: 80.09884589156965
# MSE: 0.0019068521746192636
# SSIM: 0.9147027001555399
#
# 352
# PSNR: 83.35281925136522
# MSE: 0.0009014044348724274
# SSIM: 0.960965887755102
#
# 353
# PSNR: 78.5958053214999
# MSE: 0.0026953867146740657
# SSIM: 0.9343695072484036
#
# 354
# PSNR: 77.10052960518217
# MSE: 0.0038031955398357456
# SSIM: 0.932395311981156
#
# 355
# PSNR: 82.44699665858786
# MSE: 0.0011104575206286986
# SSIM: 0.9605914785161819
#
# 356
# PSNR: 86.52054232254088
# MSE: 0.0004346577057433828
# SSIM: 0.972346294667045
#
# 357
# PSNR: 77.15078683329416
# MSE: 0.0037594380462840442
# SSIM: 0.9351907438980772
#
# 358
# PSNR: 75.67730522259008
# MSE: 0.005278020750689553
# SSIM: 0.8473486485136346
#
# 359
# PSNR: 80.70407337623507
# MSE: 0.001658800959741083
# SSIM: 0.9104742859411926
#
# 360
# PSNR: 73.70275092533113
# MSE: 0.008316230594561236
# SSIM: 0.8138843980648165
#
# 361
# PSNR: 80.72887447972175
# MSE: 0.0016493550997050354
# SSIM: 0.9385328474067127
#
# 362
# PSNR: 84.96652175215787
# MSE: 0.0006216550133433607
# SSIM: 0.97258870262755
#
# 363
# PSNR: 75.79956519669804
# MSE: 0.005131509011582583
# SSIM: 0.8781502645098661
#
# 364
# PSNR: 79.16020365516952
# MSE: 0.0023669073052631703
# SSIM: 0.9601730623780558
#
# 365
# PSNR: 80.74458042524296
# MSE: 0.001643401098990958
# SSIM: 0.9435202476960889
#
# 366
# PSNR: 74.9999332813336
# MSE: 0.0061689079149442215
# SSIM: 0.9169857452010349
#
# 367
# PSNR: 76.98725757458939
# MSE: 0.003903694817673734
# SSIM: 0.8654738617414114
#
# 368
# PSNR: 82.48017892714816
# MSE: 0.0011020054006100639
# SSIM: 0.9495160853731811
#
# 369
# PSNR: 74.01905264616528
# MSE: 0.007732080216520593
# SSIM: 0.8034231636996537
#
# 370
# PSNR: 75.8433544138685
# MSE: 0.005080028797448131
# SSIM: 0.9214337573349857
#
# 371
# PSNR: 73.63553397336992
# MSE: 0.00844594440254278
# SSIM: 0.8949318594350292
#
# 372
# PSNR: 78.60853581579542
# MSE: 0.002687497283904785
# SSIM: 0.9566384345491463
#
# 373
# PSNR: 79.5178353468042
# MSE: 0.002179807190787081
# SSIM: 0.9248080693793419
#
# 374
# PSNR: 73.94515187819553
# MSE: 0.007864777266868966
# SSIM: 0.7762566240722893
#
# 375
# PSNR: 76.23987702941426
# MSE: 0.004636752477031319
# SSIM: 0.9282834337315237
#
# 376
# PSNR: 72.94722285003775
# MSE: 0.009896447624963806
# SSIM: 0.8067745432654184
#
# 377
# PSNR: 71.58079485677449
# MSE: 0.013555705648685079
# SSIM: 0.7832537695935068
#
# 378
# PSNR: 75.60458188682722
# MSE: 0.005367146216819347
# SSIM: 0.9242918361684288
#
# 379
# PSNR: 68.87851870829539
# MSE: 0.025255137931161135
# SSIM: 0.8655678714945937
#
# 380
# PSNR: 71.3705478428779
# MSE: 0.01422809745783678
# SSIM: 0.9058873607992339
#
# 381
# PSNR: 78.3100397044933
# MSE: 0.0028787082016610223
# SSIM: 0.8988073338239323
#
# 382
# PSNR: 81.09930307608903
# MSE: 0.0015145070802450881
# SSIM: 0.9594743939468336
#
# 383
# PSNR: 84.98591231023536
# MSE: 0.000618885609627794
# SSIM: 0.9599416074370773
#
# 384
# PSNR: 76.72810019400384
# MSE: 0.004143731398616999
# SSIM: 0.9064383209276263
#
# 385
# PSNR: 78.91469750170303
# MSE: 0.002504562451978762
# SSIM: 0.9539530990573174
#
# 386
# PSNR: 78.02814932277866
# MSE: 0.0030717557741188764
# SSIM: 0.8907307110058121
#
# 387
# PSNR: 78.02364227533158
# MSE: 0.0030749452540506953
# SSIM: 0.9457313740087828
#
# 388
# PSNR: 76.31093991585742
# MSE: 0.004561499420242282
# SSIM: 0.8594743171933281
#
# 389
# PSNR: 72.0401803441636
# MSE: 0.01219504988486951
# SSIM: 0.8823440160625001
#
# 390
# PSNR: 78.51861762245082
# MSE: 0.0027437204064295275
# SSIM: 0.9160370237808838
#
# 391
# PSNR: 73.92524605931925
# MSE: 0.007900908088327791
# SSIM: 0.885914547828831
#
# 392
# PSNR: 80.84834709454125
# MSE: 0.001604600436964358
# SSIM: 0.9500092318437622
#
# 393
# PSNR: 79.73175809516704
# MSE: 0.0020750368138779396
# SSIM: 0.9618596328526948
#
# 394
# PSNR: 82.61980364003976
# MSE: 0.0010671396376978845
# SSIM: 0.961889143996248
#
# 395
# PSNR: 76.00671371670958
# MSE: 0.004892493348762565
# SSIM: 0.8747156674726706
#
# 396
# PSNR: 74.95961401048356
# MSE: 0.006226445836381104
# SSIM: 0.8160997348510876
#
# 397
# PSNR: 83.0790585425197
# MSE: 0.0009600542208803961
# SSIM: 0.9615954047125393
#
# 398
# PSNR: 78.21182978756488
# MSE: 0.00294454799014992
# SSIM: 0.8738903037481088
#
# 399
# PSNR: 80.1378889884198
# MSE: 0.0018897863891916044
# SSIM: 0.9585349064628037
#
# 400
# PSNR: 75.40515083525224
# MSE: 0.0056193558120489475
# SSIM: 0.9206905696721054
#
# 401
# PSNR: 75.39232871679894
# MSE: 0.005635970923893806
# SSIM: 0.8513560093192739
#
# 402
# PSNR: 75.64144235244588
# MSE: 0.0053217856771604075
# SSIM: 0.935525790703243
#
# 403
# PSNR: 77.80853130732703
# MSE: 0.003231085756800689
# SSIM: 0.9574450452216436
#
# 404
# PSNR: 72.37372957382978
# MSE: 0.011293502652647794
# SSIM: 0.8701518904888088
#
# 405
# PSNR: 76.8188018410352
# MSE: 0.004058087728741564
# SSIM: 0.8654959906077959
#
# 406
# PSNR: 76.48482160272857
# MSE: 0.004382475080644123
# SSIM: 0.9191419553274355
#
# 407
# PSNR: 87.85596610760534
# MSE: 0.000319598700528506
# SSIM: 0.9803069050677603
#
# 408
# PSNR: 80.03760651718648
# MSE: 0.001933930950463176
# SSIM: 0.9658058791623644
#
# 409
# PSNR: 78.62089317410336
# MSE: 0.0026798611833139573
# SSIM: 0.9073132815327764
#
# 410
# PSNR: 81.33137497913212
# MSE: 0.0014357013794926274
# SSIM: 0.942159558072362
#
# 411
# PSNR: 84.0323923875352
# MSE: 0.0007708366881724753
# SSIM: 0.958663192865776
#
# 412
# PSNR: 75.66193822751697
# MSE: 0.005296729480817686
# SSIM: 0.9177851360559908
#
# 413
# PSNR: 69.03064955889624
# MSE: 0.024385780464266902
# SSIM: 0.8168342431974578
#
# 414
# PSNR: 74.71855716896658
# MSE: 0.006581818449337608
# SSIM: 0.8958617046002519
#
# 415
# PSNR: 77.84352066052293
# MSE: 0.003205158785033808
# SSIM: 0.8903150400771044
#
# 416
# PSNR: 78.34781685447749
# MSE: 0.0028537763212007424
# SSIM: 0.9615367043374246
#
# 417
# PSNR: 78.46720650531509
# MSE: 0.002776393155297917
# SSIM: 0.9637230699317277
#
# 418
# PSNR: 82.35065610717248
# MSE: 0.001135366314484204
# SSIM: 0.95568598698241
#
# 419
# PSNR: 78.13049565792628
# MSE: 0.003000212732385998
# SSIM: 0.8042523040768952

# %% [markdown]
# ## Loss Functions

# %%
import tensorflow as tf

def SSIM(y_pred, y_true):
  return -tf.image.ssim(y_true, y_pred , max_val=2.0)

def PSNR(y_true, y_pred):
  return -tf.reduce_mean(tf.image.psnr(y_true, y_pred , max_val=2.0))

# %% [markdown]
# ### 4. Building the SRCNN Model
#
# Now that we have our low resolution images and all three image quality metrics functioning properly, we can start building the SRCNN. In Keras, it's as simple as adding layers one after the other.  The achitecture and hyper parameters of the SRCNN network can be obtained from the publication referenced above.

# %%
from loss import ae_loss
clear_session()

# define the SRCNN model
# define model type
Input_img = Input(shape=(256, 256, 3))  
    
# add model layers
l1 = Conv2D(filters=128, kernel_size = (9, 9), kernel_initializer='glorot_uniform',
                     activation='relu', padding='same', use_bias=True)(Input_img)
l2 = Conv2D(filters=64, kernel_size = (3, 3), kernel_initializer='glorot_uniform',
                     activation='relu', padding='same', use_bias=True)(l1)
result = Conv2D(filters=3, kernel_size = (5, 5), kernel_initializer='glorot_uniform',
                     activation='linear', padding='same', use_bias=True)(l2)

adam = Adam(lr=0.0003)

SRCNN = Model(Input_img, result )

# compile model
SRCNN.compile(optimizer=adam, loss=[ae_loss], metrics=['acc'])
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %% [markdown]
# ## Training the model

# %%
SRCNN.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 256, 256, 3)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 256, 256, 128)     31232
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 256, 256, 64)      73792
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 256, 256, 3)       4803
# =================================================================
# Total params: 109,827
# Trainable params: 109,827
# Non-trainable params: 0
# _________________________________________________________________

# %%
early_stopper = EarlyStopping(monitor='val_loss', min_delta=0.01, patience=50, verbose=1, mode='min')
model_checkpoint =  ModelCheckpoint('superResolution_checkpoint3.h5', save_best_only = True)

# %%
history = SRCNN.fit(train_x_low,train_x,
            epochs=10,
            validation_data=(val_x_low, val_x),
            callbacks=[early_stopper, model_checkpoint])
# Out:
# Epoch 1/10
# 53/53 [==============================] - 62s 439ms/step - loss: 0.0420 - acc: 0.4369 - val_loss: 0.0113 - val_acc: 0.6811
# Epoch 2/10
# 53/53 [==============================] - 20s 383ms/step - loss: 0.0077 - acc: 0.6863 - val_loss: 0.0063 - val_acc: 0.7014
# Epoch 3/10
# 53/53 [==============================] - 21s 391ms/step - loss: 0.0049 - acc: 0.8110 - val_loss: 0.0050 - val_acc: 0.8054
# Epoch 4/10
# 53/53 [==============================] - 21s 399ms/step - loss: 0.0043 - acc: 0.8343 - val_loss: 0.0049 - val_acc: 0.8447
# Epoch 5/10
# 53/53 [==============================] - 21s 393ms/step - loss: 0.0039 - acc: 0.8567 - val_loss: 0.0043 - val_acc: 0.8515
# Epoch 6/10
# 53/53 [==============================] - 21s 390ms/step - loss: 0.0036 - acc: 0.8699 - val_loss: 0.0040 - val_acc: 0.8532
# Epoch 7/10
# 53/53 [==============================] - 21s 391ms/step - loss: 0.0035 - acc: 0.8526 - val_loss: 0.0046 - val_acc: 0.8747
# Epoch 8/10
# 53/53 [==============================] - 21s 394ms/step - loss: 0.0034 - acc: 0.8296 - val_loss: 0.0038 - val_acc: 0.8623
# Epoch 9/10
# 53/53 [==============================] - 21s 392ms/step - loss: 0.0032 - acc: 0.8752 - val_loss: 0.0039 - val_acc: 0.8164
# Epoch 10/10
# 53/53 [==============================] - 21s 393ms/step - loss: 0.0032 - acc: 0.8770 - val_loss: 0.0036 - val_acc: 0.8738

# %% [markdown]
# ### 5. Deploying the SRCNN
#
# Now that we have defined our model, we can use it for single-image super-resolution.  However, before we do this, we will need to define a couple of image processing functions.  Furthermore, it will be necessary to preprocess the images extensively before using them as inputs to the network.  This processing will include cropping and color space conversions.
#
# Additionally, to save us the time it takes to train a deep neural network, we will be loading pre-trained weights for the SRCNN.  These weights can be found at the following GitHub page: https://github.com/MarkPrecursor/SRCNN-keras
#
# Once we have tested our network, we can perform single-image super-resolution on all of our input images. Furthermore, after processing, we can calculate the PSNR, MSE, and SSIM on the images that we produce. We can save these images directly or create subplots to conveniently display the original, low resolution, and high resolution images side by side.

# %%
# define necessary image processing functions

def modcrop(img, scale):
    tmpsz = img.shape
    sz = tmpsz[0:2]
    sz = sz - np.mod(sz, scale)
    img = img[0:sz[0], 1:sz[1]]
    return img


def shave(image, border):
    img = image[border: -border, border: -border]
    return img

# %%
val_x_low.shape
# Out:
# (420, 256, 256, 3)

# %%
# define main prediction function

    
# load the srcnn model with weights
SRCNN.load_weights('/content/superResolution_checkpoint3.h5')
    
predictions = SRCNN.predict(val_x_low)

# %%
def predict(image_index):
  # image quality calculations
  ref = val_x[image_index]
  degraded = val_x_low[image_index]
  output = predictions[image_index]
  scores = []
  scores.append(compare_images(val_x_low[i], val_x[i]))
  scores.append(compare_images(predictions[i], val_x[i]))
    
  # return images and scores
  return ref, degraded, output, scores

# %%
from random import randint
av = len(val_x)
n = 3
fig, axs = plt.subplots(n, 3, figsize=(20, 20))
if n == 1 :
  example = randint(0,av)
  axs[0].imshow(val_x[example])
  axs[0].get_xaxis().set_visible(False)
  axs[0].get_yaxis().set_visible(False)

  axs[1].imshow(val_x_low[example])
  axs[1].get_xaxis().set_visible(False)
  axs[1].get_yaxis().set_visible(False)

  axs[2].imshow(predictions[example])
  axs[2].get_xaxis().set_visible(False)
  axs[2].get_yaxis().set_visible(False)
else :
  for i in range(n):
    example = randint(0,av)
    axs[i][0].imshow(val_x[example])
    axs[i][0].get_xaxis().set_visible(False)
    axs[i][0].get_yaxis().set_visible(False)

    axs[i][1].imshow(val_x_low[example])
    axs[i][1].get_xaxis().set_visible(False)
    axs[i][1].get_yaxis().set_visible(False)


    axs[i][2].imshow(predictions[example])
    axs[i][2].get_xaxis().set_visible(False)

    axs[i][2].get_yaxis().set_visible(False)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
def Psnr(im1 , im2 , max_value = 1.0):
  im1 = tf.image.convert_image_dtype(im1, tf.float32)
  im2 = tf.image.convert_image_dtype(im2, tf.float32)
  psnr = tf.image.psnr(im1, im2, max_val= max_value)
  return float(psnr)

def mse(target, ref):
    # the MSE between the two images is the sum of the squared difference between the two images
    err = np.sum((target.astype('float') - ref.astype('float')) ** 2)
    err /= float(target.shape[0] * target.shape[1])
    
    return err

def SSIM(im1 , im2 , max_value = 2.0):
  im1 = tf.image.convert_image_dtype(im1, tf.float32)
  im2 = tf.image.convert_image_dtype(im2, tf.float32)
  SSIM = tf.image.ssim(im1, im2, max_val= max_value)
  return float(SSIM)

# %%
ssim = list(map(SSIM,predictions,val_x_low))
mse = list(map(mse, predictions, val_x_low))
Psnr = list(map(Psnr , predictions , val_x_low))

# %%
metrics = pd.DataFrame(list(zip(ssim, Psnr, mse)), 
               columns =['SSIM','PSNR', 'mse' ])

# %%
metrics.head()
# Out:
#        SSIM       PSNR       mse
# 0  0.974256  32.282562  0.001774
# 1  0.971521  32.950531  0.001521
# 2  0.966439  33.861916  0.001233
# 3  0.961048  29.975811  0.003017
# 4  0.970735  32.419609  0.001719

# %%
metrics.mean(axis = 0)
# Out:
# SSIM     0.963975
# PSNR    32.824377
# mse      0.002282
# dtype: float64

# %%
loss_train = history.history['loss']
loss_val = history.history['val_loss']
epochs = range(1,11)
plt.plot(epochs, loss_train, 'g', label='Training loss')
plt.plot(epochs, loss_val, 'b', label='validation loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
loss_train = history.history['acc']
loss_val = history.history['val_acc']
epochs = range(1,11)
plt.plot(epochs, loss_train, 'g', label='Training accuracy')
plt.plot(epochs, loss_val, 'b', label='validation accuracy')
plt.title('Training and Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
SRCNN.load_weights('/content/superResolution_checkpoint3.h5')

# %%
# !mkdir /content/test/

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))

# %%
from skimage.transform import resize
def preprocess_uploaded_test(filepath):
  image = cv2.imread(filepath ,cv2.IMREAD_COLOR)
  HighRes = resize(image, (256, 256))
  # Add this image to the high res dataset
  # Rescale it 0.5x and 2x so that it is a low res image but still has 256x256 resolution
  LowRes = get_low_res(HighRes , factor = 2)
  return HighRes , LowRes

# %%
HR , LR = preprocess_uploaded_test('/content/buildings15.tif')

# %%
test_results = predictions = SRCNN.predict(np.reshape(LR,(1,256,256,3)))

# %%
fig, axs = plt.subplots(1, 3, figsize=(20, 20))
axs[0].imshow(HR)
axs[0].get_xaxis().set_visible(False)
axs[0].get_yaxis().set_visible(False)

axs[1].imshow(LR)
axs[1].get_xaxis().set_visible(False)
axs[1].get_yaxis().set_visible(False)

axs[2].imshow(test_results[0])
axs[2].get_xaxis().set_visible(False)
axs[2].get_yaxis().set_visible(False)
